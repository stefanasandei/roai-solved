# %%
import math

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier

# %%
seed = 42

# %% [markdown]
# # Data preparation

# %%
def clean_df(df):
    return df

def prep_features(df):
    df = df.drop(["Credit_Score", "ID", "Customer_ID", "SSN"], axis=1, errors='ignore')

    dummy_cols = ["Credit_Mix", "Payment_of_Min_Amount", "Payment_Behaviour"]
    dummies_df = pd.get_dummies(df[dummy_cols], prefix=dummy_cols, drop_first=True)
    df = df.drop(dummy_cols, axis=1)
    df = pd.concat([df, dummies_df], axis=1)

    def parse(value):
        parts = value.split()
        years = int(parts[0])
        months = int(parts[3])
        return years * 12 + months
    df["Credit_History_Age"] = df["Credit_History_Age"].apply(parse)

    df = df.drop(df.select_dtypes(include='object'), axis=1)

    return df

# %%
df = pd.read_csv("train_data.csv")
df = clean_df(df)

df_train = prep_features(df)

# %%
df_train.head()
# Out:
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0            4997.530000                  9                7             19
# 1            1334.804167                  8              583             22
# 2            8600.050000                  8                6              4
# 3           11888.193333                  5                2              4
# 4            1851.335000                  4                3              6
#
#    Delay_from_due_date  Num_Credit_Inquiries  Credit_Utilization_Ratio  \
# 0                   58                   8.0                 31.737712
# 1                   20                   9.0                 27.414562
# 2                   18                   2.0                 36.516160
# 3                    3                   2.0                 36.955252
# 4                   10                   0.0                 28.542585
#
#    Credit_History_Age  Total_EMI_per_month  Credit_Mix_Good  \
# 0                 166           339.971582            False
# 1                  27            67.975819            False
# 2                 351           143.856735             True
# 3                 369           182.160424             True
# 4                 242            25.580281            False
#
#    Credit_Mix_Standard  Credit_Mix__  Payment_of_Min_Amount_No  \
# 0                False          True                     False
# 1                False         False                     False
# 2                False         False                      True
# 3                False         False                      True
# 4                False          True                      True
#
#    Payment_of_Min_Amount_Yes  \
# 0                       True
# 1                       True
# 2                      False
# 3                      False
# 4                      False
#
#    Payment_Behaviour_High_spent_Large_value_payments  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#    Payment_Behaviour_High_spent_Medium_value_payments  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    Payment_Behaviour_High_spent_Small_value_payments  \
# 0                                               True
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Payment_Behaviour_Low_spent_Large_value_payments  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                              True
#
#    Payment_Behaviour_Low_spent_Medium_value_payments  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Payment_Behaviour_Low_spent_Small_value_payments
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False

# %% [markdown]
# # Exploratory data analysis

# %%
df_train.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           44207.000000       44207.000000     44207.000000
# mean             4019.547959          16.771281        23.223109
# std              3092.839667         114.890173       130.872496
# min               303.645417          -1.000000         0.000000
# 25%              1574.695833           4.000000         4.000000
# 50%              2986.346667           6.000000         6.000000
# 75%              5704.220000           8.000000         7.000000
# max             15204.633333        1798.000000      1499.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count   44207.000000         44207.000000          44207.000000
# mean       77.300925            22.054652             26.791504
# std       483.025792            15.253947            185.571018
# min         1.000000            -5.000000              0.000000
# 25%         8.000000            10.000000              3.000000
# 50%        15.000000            19.000000              6.000000
# 75%        22.000000            29.000000              9.000000
# max      5789.000000            67.000000           2594.000000
#
#        Credit_Utilization_Ratio  Credit_History_Age  Total_EMI_per_month
# count              44207.000000        44207.000000         44207.000000
# mean                  32.213410          213.094736          1451.435871
# std                    5.055008          100.125007          8446.131137
# min                   21.264254            2.000000             4.462837
# 25%                   28.035357          134.000000            41.132527
# 50%                   32.239814          212.000000            78.369329
# 75%                   36.402076          292.000000           168.955552
# max                   49.564519          404.000000         82331.000000

# %% [markdown]
# # Models

# %%
X_train, X_val, y_train, y_val = train_test_split(df_train, df["Credit_Score"], test_size=0.2, random_state=seed)

# %%
def evaluate(clf):
    scores = cross_val_score(clf, X_train, y_train, cv=3)
    return np.mean(scores) - np.std(scores)

# %%
rf = RandomForestClassifier(n_estimators=300, random_state=seed)

rf.fit(X_train, y_train)
print(rf.score(X_val, y_val))

evaluate(rf)
# Out:
# 0.744288622483601
# np.float64(0.7215864193836834)

# %%
clf = rf

# %% [markdown]
# # Submission

# %%
test_df = pd.read_csv("test_data.csv")
test_df = clean_df(test_df)
features = prep_features(test_df)

# %%
subtask1 = len(df_train)
subtask2 = math.floor(df_train[df_train["Credit_Utilization_Ratio"] >= 25]["Monthly_Inhand_Salary"].mean())
subtask3 = df["Month"].nunique()
subtask4 = df["SSN"][df["SSN"].str.endswith('20')].nunique()

# %%
subtasks12 = pd.DataFrame({
    "subtaskID": [1, 2, 3,4],
    "datapointID": 1,
    "answer": [subtask1, subtask2, subtask3, subtask4]
})

subtask3 = pd.DataFrame({
    "subtaskID": 5,
    "datapointID": test_df["ID"],
    "answer": clf.predict(features)
})

submission = pd.concat([subtasks12, subtask3])
submission.head()
# Out:
#    subtaskID datapointID  answer
# 0          1           1   44207
# 1          2           1    4106
# 2          3           1       8
# 3          4           1     109
# 0          5     0x1c2a8       0

# %%
submission.to_csv("submission.csv", index=False)
